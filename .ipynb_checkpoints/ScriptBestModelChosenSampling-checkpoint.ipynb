# %%
#pip install --upgrade --force-reinstall matplotlib

# %%
import pandas as pd
import numpy as np
import json
import re

# %%
import matplotlib as plt

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# #### Učitavanje podataka

# %%
data_attrition=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data_attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# #### Proveravanje null vrednosti u skupu podataka

# %%
data_attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
##### Proveravamo da li nam se u skupu podataka 
maska = data_attrition.isnull() | (data_attrition == '') | (data_attrition == 'None') | (data_attrition == ' ')

# %%
broj_null_vrednosti = maska.sum()
print(broj_null_vrednosti)
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
### Provera duplikata je takodje jedna od tehnika koje su neophodne u generisanju i preprocesiranju modela mašinskog učenja
## Nekada se radi svesno oversemplovanje ili undersamplovanje skupa podataka za treniranje medjutim u ovom slučaju je
# bolje na početku proveriti i uveriti se da li u samom startu postoje vrednosti koje su duplirane
###

# %%
podaci_duplirani= data_attrition.duplicated()

# %%
# SADA DA VIDIMO DA LI SU PODACI DUPLIRANI
data_attrition[podaci_duplirani]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
#-Podaci u početnom skupu podataka nisu duplirani i nalaze se normalno

# %%
#### Provera unique vrednosti unutar kolona 
#### kako bi izbegle i izbrisale konstantne vrednosti u skupu podataka koje nisu korisne ili su neke informacije
### poput ID kolona koji nisu kasnije relevantne za analizu

# %%
data_attrition.shape
# Out:
# (1470, 35)

# %%
for kolona in data_attrition.columns:
    print(f"{kolona}: Ima jedinstvenih vrednosti {data_attrition[kolona].nunique()}")
    print("######################################################")
# Out:
# Age: Ima jedinstvenih vrednosti 43
# ######################################################
# Attrition: Ima jedinstvenih vrednosti 2
# ######################################################
# BusinessTravel: Ima jedinstvenih vrednosti 3
# ######################################################
# DailyRate: Ima jedinstvenih vrednosti 886
# ######################################################
# Department: Ima jedinstvenih vrednosti 3
# ######################################################
# DistanceFromHome: Ima jedinstvenih vrednosti 29
# ######################################################
# Education: Ima jedinstvenih vrednosti 5
# ######################################################
# EducationField: Ima jedinstvenih vrednosti 6
# ######################################################
# EmployeeCount: Ima jedinstvenih vrednosti 1
# ######################################################
# EmployeeNumber: Ima jedinstvenih vrednosti 1470
# ######################################################
# EnvironmentSatisfaction: Ima jedinstvenih vrednosti 4
# ######################################################
# Gender: Ima jedinstvenih vrednosti 2
# ######################################################
# HourlyRate: Ima jedinstvenih vrednosti 71
# ######################################################
# JobInvolvement: Ima jedinstvenih vrednosti 4
# ######################################################
# JobLevel: Ima jedinstvenih vrednosti 5
# ######################################################
# JobRole: Ima jedinstvenih vrednosti 9
# ######################################################
# JobSatisfaction: Ima jedinstvenih vrednosti 4
# ######################################################
# MaritalStatus: Ima jedinstvenih vrednosti 3
# ######################################################
# MonthlyIncome: Ima jedinstvenih vrednosti 1349
# ######################################################
# MonthlyRate: Ima jedinstvenih vrednosti 1427
# ######################################################
# NumCompaniesWorked: Ima jedinstvenih vrednosti 10
# ######################################################
# Over18: Ima jedinstvenih vrednosti 1
# ######################################################
# OverTime: Ima jedinstvenih vrednosti 2
# ######################################################
# PercentSalaryHike: Ima jedinstvenih vrednosti 15
# ######################################################
# PerformanceRating: Ima jedinstvenih vrednosti 2
# ######################################################
# RelationshipSatisfaction: Ima jedinstvenih vrednosti 4
# ######################################################
# StandardHours: Ima jedinstvenih vrednosti 1
# ######################################################
# StockOptionLevel: Ima jedinstvenih vrednosti 4
# ######################################################
# TotalWorkingYears: Ima jedinstvenih vrednosti 40
# ######################################################
# TrainingTimesLastYear: Ima jedinstvenih vrednosti 7
# ######################################################
# WorkLifeBalance: Ima jedinstvenih vrednosti 4
# ######################################################
# YearsAtCompany: Ima jedinstvenih vrednosti 37
# ######################################################
# YearsInCurrentRole: Ima jedinstvenih vrednosti 19
# ######################################################
# YearsSinceLastPromotion: Ima jedinstvenih vrednosti 16
# ######################################################
# YearsWithCurrManager: Ima jedinstvenih vrednosti 18
# ######################################################

# %%
for kolona in data_attrition.columns:
    if data_attrition[kolona].nunique()==1:
        print(f"{kolona}: Ima jednu jedinstvenu vrednosti {data_attrition[kolona].nunique()}")
        print("######################################################")
    elif data_attrition[kolona].nunique()==data_attrition.shape[0]:
        print(f"{kolona}: Ima sve različite vrednosti")
        print("######################################################")
# Out:
# EmployeeCount: Ima jednu jedinstvenu vrednosti 1
# ######################################################
# EmployeeNumber: Ima sve različite vrednosti
# ######################################################
# Over18: Ima jednu jedinstvenu vrednosti 1
# ######################################################
# StandardHours: Ima jednu jedinstvenu vrednosti 1
# ######################################################

# %%
## pre nego što ove informacije budu iskorišćene za prečišćavanje skupa podataka možemo videti raspodelu

# %%
data_attrition.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'Education'}>,
#         <Axes: title={'center': 'EmployeeCount'}>],
#        [<Axes: title={'center': 'EmployeeNumber'}>,
#         <Axes: title={'center': 'EnvironmentSatisfaction'}>,
#         <Axes: title={'center': 'HourlyRate'}>,
#         <Axes: title={'center': 'JobInvolvement'}>,
#         <Axes: title={'center': 'JobLevel'}>],
#        [<Axes: title={'center': 'JobSatisfaction'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>,
#         <Axes: title={'center': 'PercentSalaryHike'}>],
#        [<Axes: title={'center': 'PerformanceRating'}>,
#         <Axes: title={'center': 'RelationshipSatisfaction'}>,
#         <Axes: title={'center': 'StandardHours'}>,
#         <Axes: title={'center': 'StockOptionLevel'}>,
#         <Axes: title={'center': 'TotalWorkingYears'}>],
#        [<Axes: title={'center': 'TrainingTimesLastYear'}>,
#         <Axes: title={'center': 'WorkLifeBalance'}>,
#         <Axes: title={'center': 'YearsAtCompany'}>,
#         <Axes: title={'center': 'YearsInCurrentRole'}>,
#         <Axes: title={'center': 'YearsSinceLastPromotion'}>],
#        [<Axes: title={'center': 'YearsWithCurrManager'}>, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
# Na osnovu prikazanih histograma mogu se izneti sl. zaključci:
# - Dobra većina varijabli imaju distribuciju gde su krajevi raspodele izuzetno opterećeni,
## tako reći to su raspodele verovatnoća čiji repovi (krajevi) nisu eksponencijalno ograničeni. 
# To onda znači da oni opadaju sporije od ekponencijalne raspodele.
# u našem slučaju to bi značilo da većina varijabli ima raspodelu nakrivljenu na desno.
### Takođe vidimo da su neke varijable konstantne i da je moguće da se izbace i ne proučavaju dalje.

# %%
##### Ovde se zakljucuje da je neophodno ukoliti kolone koje imaju standardnu vrednost poput EmployeeCount, StandardHours Over18 a da
#varijabla EmployeeNumber predstavlja

# %%
data_attrition.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True                      )

# %%
data_attrition.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        0                    5
# 1                   7                        1                    7
# 2                   0                        0                    0
# 3                   7                        3                    0
# 4                   2                        2                    2
#
# [5 rows x 31 columns]

# %%
### yes - 1; no -0
label_encoder_output = LabelEncoder()
data_attrition['Attrition'] = label_encoder_output.fit_transform(data_attrition['Attrition'])
# Out:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
data_attrition.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        0                    5
# 1                   7                        1                    7
# 2                   0                        0                    0
# 3                   7                        3                    0
# 4                   2                        2                    2
#
# [5 rows x 31 columns]

# %%
#data_attrition.head(5).to_csv("sample21.07.csv", index=False)

# %%
## sledeći korak je da se odradi uklanjanje outlier-a 
# - tu mogu da se koriste dve technike sada ćemo odraditi tehniku koriščenjem Z-score-a ali posto je takav vid uklanjanja oulier-a
## preporucljiv iskljucivo sa numerickim vrednostima potrebno je da se dobro razumeju sve kolone i shodno tome da se razdvoje
#### u odgovarajuće tipove podatka

# %%
data_attrition.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
numeričke_varijable=['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome',
                     'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears',
                    'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 
                    'YearsSinceLastPromotion']

# %%
kategoričke_nominalne=['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']

# %%
izlazna_varijabla=['Attrition']

# %%
kategoričke_binarne=['Gender', 'OverTime']

# %%
kategoričke_ordinalne=['Education', 'EnvironmentSatisfaction', 'JobInvolvement', 
                       'JobLevel', 'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction',
                       'StockOptionLevel', 'WorkLifeBalance']

# %%
###### Ispod je predstavljena tehnika otklanjanja outlier-a na osnovu z-scorea

# %%
data_attrition.shape
# Out:
# (1470, 31)

# %%
###
import numpy as np
from scipy import stats

# %%
z_skorovi = np.abs(stats.zscore(data_attrition[numeričke_varijable]))
data_attrition_outlier_cleaned = data_attrition[(z_skorovi < 3).all(axis=1)]

# %%
data_attrition_outlier_cleaned.shape
# Out:
# (1393, 31)

# %%
#### Sledeći korak jeste feature engineering u kome ćemo dodati odredjene izvedene varijable

# %%
data_attrition_obogacen= data_attrition_outlier_cleaned.copy()

# %%
data_attrition_obogacen['YearsAtCompany_ManagerRatio'] = data_attrition_obogacen['YearsAtCompany'] / (data_attrition_obogacen['YearsWithCurrManager'] + 1)
data_attrition_obogacen['SalaryIncreasePerYear']=(data_attrition_obogacen['MonthlyIncome']-data_attrition_obogacen['DailyRate']*22) / data_attrition_obogacen['YearsAtCompany']

# %%
data_attrition_obogacen.shape
# Out:
# (1393, 33)

# %%
### sada se dodaju ove dve numericke varijable u numericke varijable i onda je potrebno da će biti odradjena 
##odgovarajuća konverzija kategorickih varijabli u numerickih kao i skaliranje numerickih varijabli

# %%
numeričke_varijable.append('YearsAtCompany_ManagerRatio')
numeričke_varijable.append('SalaryIncreasePerYear')

# %%
numeričke_varijable
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsSinceLastPromotion',
#  'YearsAtCompany_ManagerRatio',
#  'SalaryIncreasePerYear']

# %%
##### konverzija kategorickih u numericke

# %%
### prvo kategoricke ordinalne konvertujemo u ordinal varijable

# %%
import warnings

warnings.filterwarnings('ignore', category=FutureWarning, message='is_sparse is deprecated')

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
label_encoders = {}
for kolona in kategoričke_ordinalne:
    le = LabelEncoder()
    data_attrition_obogacen[kolona] = le.fit_transform(data_attrition_obogacen[kolona])
    label_encoders[kolona] = le

# %%
data_attrition_obogacen = pd.get_dummies(data_attrition_obogacen, columns= kategoričke_nominalne + kategoričke_binarne, drop_first=True)

# %%
#### Sada se koristi Standard Scaler za skaliranje numerickih varijabli

# %%
###3 ! ovo je zbog izvedenih varijabli 
data_attrition_obogacen.replace([np.inf, -np.inf], np.nan, inplace=True)
data_attrition_obogacen.dropna(inplace=True)

# %%
data_attrition_obogacen.shape
# Out:
# (1349, 47)

# %%
scaler = StandardScaler()
data_attrition_obogacen[numeričke_varijable] = scaler.fit_transform(data_attrition_obogacen[numeričke_varijable])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=30)
data_pca = pca.fit_transform(data_attrition_obogacen.drop(columns=['Attrition']))
data_pca = pd.DataFrame(data_pca, columns=[f'PC{i}' for i in range(1, 31)])
data_pca['Attrition'] = data_attrition_obogacen['Attrition'].values

# %%
data_pca
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     0.711770  0.180785 -1.318192  0.166418  1.248473  0.335596 -1.307576
# 1     3.159184 -0.573361  0.253168 -0.678110 -0.654776 -0.635838 -0.409364
# 2    -3.662890  1.205928  3.894188  2.083281 -1.671700  0.505736  1.414320
# 3    -2.546406 -0.837006 -0.838595 -1.343141 -0.212830 -1.297946  0.783203
# 4     1.879660 -2.020219  0.433864  1.211545 -0.769891 -1.043994 -0.546271
# ...        ...       ...       ...       ...       ...       ...       ...
# 1344 -1.151108  0.136629 -0.172193  0.966428  0.360960 -0.926199 -0.420332
# 1345  3.158962  0.060589  0.007091 -0.291783 -1.763678  1.837144 -1.318468
# 1346 -1.123677 -0.586440  0.562905 -1.699787  1.283225  0.721624 -0.674095
# 1347  4.055108 -0.021770 -1.168893 -0.045783 -1.659889 -0.864287  0.020031
# 1348 -2.107190 -0.296447  0.595039 -0.655482  1.026782  0.943793 -0.121222
#
#            PC8       PC9      PC10  ...      PC22      PC23      PC24  \
# 0    -0.259369 -1.541790 -2.313511  ... -0.486287 -0.064316  0.462898
# 1    -0.578623  3.100970  0.581937  ... -0.238720  0.457940 -0.621945
# 2     1.804682 -1.609086  0.680831  ... -0.370692  0.789654 -0.849806
# 3    -1.531875 -0.084971  0.407036  ...  0.230097 -0.420537 -0.621307
# 4     0.211750 -0.866270 -0.525367  ... -0.848037  0.838810 -0.012186
# ...        ...       ...       ...  ...       ...       ...       ...
# 1344  0.295048  1.163818 -0.535309  ...  0.252190  1.014303 -0.827787
# 1345 -2.661179  0.684975  0.660742  ... -0.002101 -0.504573 -0.624279
# 1346  0.953868  0.900928  0.172956  ...  0.347507 -0.403390 -0.227383
# 1347  0.030634 -0.255046  0.675860  ... -0.106492  0.942920 -1.167118
# 1348 -0.496417 -1.288134 -0.352387  ...  0.343278 -0.412933 -0.873087
#
#           PC25      PC26      PC27      PC28      PC29      PC30  Attrition
# 0     0.292590  0.558127 -0.639181  0.516029  0.426997 -0.301687          1
# 1    -0.228991 -0.262356 -0.157829  0.445086 -0.985650 -0.104737          0
# 2     1.135100  0.552124  0.279137  0.730429 -0.044951 -0.033835          0
# 3    -0.214161 -0.429747 -0.128568 -0.249528  0.473203 -0.069401          0
# 4    -0.597896 -0.559495 -0.181424 -0.574547  0.540684 -0.011824          0
# ...        ...       ...       ...       ...       ...       ...        ...
# 1344 -0.121185 -0.547454  0.650174 -0.765385  0.580950 -0.170418          0
# 1345 -0.461831 -0.408248 -0.821907  0.552081 -0.448887 -0.242195          0
# 1346  0.286824 -0.023004  0.031285  0.628616  0.527025 -0.137972          0
# 1347 -0.241697 -0.486615  0.194427 -0.185227 -0.210093 -0.673715          0
# 1348 -0.273232 -0.494175 -0.463953 -0.117359  0.495464 -0.188254          0
#
# [1349 rows x 31 columns]

# %%
### podela skupa podataka na treniranje i testiranje

# %%
from sklearn.model_selection import train_test_split

# %%
X_ulazi = data_pca.drop(columns=['Attrition'])
y_izlaz = data_pca['Attrition']
X_train, X_test, y_train, y_test = train_test_split(X_ulazi, y_izlaz, test_size=0.2, random_state=42, stratify=y_izlaz)

# %%
######### obrizom na ne balansiranost klasa potrebno je uraditi i balansking samih klasa

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

# %%
############# TRENIRANJE RAZLICITIH TIPOVA MODELA ZA RESAVANJE MODELA KLASIFIKACIJE ZAPOSLENIH###########

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.5.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from lightgbm) (1.26.3)
# Requirement already satisfied: scipy in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from lightgbm) (1.10.1)
# Downloading lightgbm-4.5.0-py3-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.4 MB 871.5 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.4 MB 1.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 3.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.4 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\andjelami\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp39-cp39-win_amd64.whl.metadata (1.2 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from catboost) (1.26.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from catboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from catboost) (5.22.0)
# Requirement already satisfied: six in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\andjelami\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Downloading catboost-1.2.5-cp39-cp39-win_amd64.whl (101.2 MB)
#    ---------------------------------------- 0.0/101.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/101.2 MB 3.0 MB/s eta 0:00:34
#    ---------------------------------------- 0.3/101.2 MB 3.5 MB/s eta 0:00:29
#    ---------------------------------------- 0.5/101.2 MB 3.8 MB/s eta 0:00:27
#    ---------------------------------------- 1.0/101.2 MB 5.6 MB/s eta 0:00:18
#     --------------------------------------- 1.3/101.2 MB 6.0 MB/s eta 0:00:17
#     --------------------------------------- 2.0/101.2 MB 7.2 MB/s eta 0:00:14
#    - -------------------------------------- 2.7/101.2 MB 8.3 MB/s eta 0:00:12
#    - -------------------------------------- 3.2/101.2 MB 8.8 MB/s eta 0:00:12
#    - -------------------------------------- 3.9/101.2 MB 9.3 MB/s eta 0:00:11
#    - -------------------------------------- 4.8/101.2 MB 10.2 MB/s eta 0:00:10
#    -- ------------------------------------- 5.7/101.2 MB 11.4 MB/s eta 0:00:09
#    -- ------------------------------------- 6.0/101.2 MB 10.6 MB/s eta 0:00:09
#    -- ------------------------------------- 6.7/101.2 MB 11.4 MB/s eta 0:00:09
#    --- ------------------------------------ 7.7/101.2 MB 11.7 MB/s eta 0:00:08
#    --- ------------------------------------ 8.3/101.2 MB 11.8 MB/s eta 0:00:08
#    --- ------------------------------------ 9.2/101.2 MB 12.2 MB/s eta 0:00:08
#    --- ------------------------------------ 10.0/101.2 MB 12.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 10.6/101.2 MB 14.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 11.6/101.2 MB 15.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 12.1/101.2 MB 15.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 13.0/101.2 MB 15.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 13.9/101.2 MB 16.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 14.4/101.2 MB 16.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 15.1/101.2 MB 15.6 MB/s eta 0:00:06
#    ------ --------------------------------- 16.0/101.2 MB 15.6 MB/s eta 0:00:06
#    ------ --------------------------------- 16.9/101.2 MB 16.4 MB/s eta 0:00:06
#    ------ --------------------------------- 17.3/101.2 MB 15.6 MB/s eta 0:00:06
#    ------- -------------------------------- 18.0/101.2 MB 15.6 MB/s eta 0:00:06
#    ------- -------------------------------- 18.9/101.2 MB 16.0 MB/s eta 0:00:06
#    ------- -------------------------------- 19.5/101.2 MB 16.0 MB/s eta 0:00:06
#    -------- ------------------------------- 20.3/101.2 MB 16.0 MB/s eta 0:00:06
#    -------- ------------------------------- 21.1/101.2 MB 16.0 MB/s eta 0:00:06
#    -------- ------------------------------- 21.5/101.2 MB 15.6 MB/s eta 0:00:06
#    -------- ------------------------------- 22.2/101.2 MB 15.2 MB/s eta 0:00:06
#    --------- ------------------------------ 23.1/101.2 MB 15.6 MB/s eta 0:00:06
#    --------- ------------------------------ 23.9/101.2 MB 15.6 MB/s eta 0:00:05
#    --------- ------------------------------ 24.4/101.2 MB 15.2 MB/s eta 0:00:06
#    --------- ------------------------------ 25.0/101.2 MB 14.9 MB/s eta 0:00:06
#    ---------- ----------------------------- 26.7/101.2 MB 16.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 27.7/101.2 MB 16.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 28.6/101.2 MB 17.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 29.2/101.2 MB 17.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 29.9/101.2 MB 17.3 MB/s eta 0:00:05
#    ------------ --------------------------- 30.4/101.2 MB 16.4 MB/s eta 0:00:05
#    ------------ --------------------------- 31.9/101.2 MB 18.2 MB/s eta 0:00:04
#    ------------ --------------------------- 32.6/101.2 MB 18.7 MB/s eta 0:00:04
#    ------------- -------------------------- 33.2/101.2 MB 17.7 MB/s eta 0:00:04
#    ------------- -------------------------- 34.0/101.2 MB 17.7 MB/s eta 0:00:04
#    ------------- -------------------------- 34.6/101.2 MB 18.7 MB/s eta 0:00:04
#    -------------- ------------------------- 35.4/101.2 MB 18.2 MB/s eta 0:00:04
#    -------------- ------------------------- 35.6/101.2 MB 17.2 MB/s eta 0:00:04
#    -------------- ------------------------- 36.2/101.2 MB 16.4 MB/s eta 0:00:04
#    -------------- ------------------------- 36.9/101.2 MB 15.2 MB/s eta 0:00:05
#    -------------- ------------------------- 37.6/101.2 MB 15.2 MB/s eta 0:00:05
#    --------------- ------------------------ 38.6/101.2 MB 14.9 MB/s eta 0:00:05
#    --------------- ------------------------ 39.5/101.2 MB 15.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 40.6/101.2 MB 16.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 41.7/101.2 MB 16.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 42.6/101.2 MB 16.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 43.5/101.2 MB 16.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 44.5/101.2 MB 16.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 44.7/101.2 MB 16.4 MB/s eta 0:00:04
#    ------------------ --------------------- 45.9/101.2 MB 17.2 MB/s eta 0:00:04
#    ------------------ --------------------- 46.6/101.2 MB 18.2 MB/s eta 0:00:03
#    ------------------- -------------------- 48.4/101.2 MB 19.9 MB/s eta 0:00:03
#    ------------------- -------------------- 49.0/101.2 MB 18.7 MB/s eta 0:00:03
#    ------------------- -------------------- 49.3/101.2 MB 18.7 MB/s eta 0:00:03
#    -------------------- ------------------- 50.7/101.2 MB 18.7 MB/s eta 0:00:03
#    -------------------- ------------------- 51.5/101.2 MB 18.7 MB/s eta 0:00:03
#    -------------------- ------------------- 52.2/101.2 MB 18.7 MB/s eta 0:00:03
#    -------------------- ------------------- 53.0/101.2 MB 17.7 MB/s eta 0:00:03
#    --------------------- ------------------ 53.7/101.2 MB 17.7 MB/s eta 0:00:03
#    --------------------- ------------------ 54.6/101.2 MB 17.7 MB/s eta 0:00:03
#    --------------------- ------------------ 55.5/101.2 MB 19.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 56.4/101.2 MB 19.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 57.0/101.2 MB 19.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 58.0/101.2 MB 18.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 58.4/101.2 MB 17.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 59.4/101.2 MB 17.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 60.2/101.2 MB 18.2 MB/s eta 0:00:03
#    ------------------------ --------------- 61.1/101.2 MB 17.7 MB/s eta 0:00:03
#    ------------------------ --------------- 62.2/101.2 MB 17.7 MB/s eta 0:00:03
#    ------------------------ --------------- 63.1/101.2 MB 18.7 MB/s eta 0:00:03
#    ------------------------- -------------- 64.0/101.2 MB 18.7 MB/s eta 0:00:02
#    ------------------------- -------------- 64.9/101.2 MB 18.7 MB/s eta 0:00:02
#    ------------------------- -------------- 65.1/101.2 MB 17.7 MB/s eta 0:00:03
#    -------------------------- ------------- 66.0/101.2 MB 17.3 MB/s eta 0:00:03
#    -------------------------- ------------- 66.9/101.2 MB 17.2 MB/s eta 0:00:02
#    -------------------------- ------------- 67.3/101.2 MB 17.7 MB/s eta 0:00:02
#    -------------------------- ------------- 67.6/101.2 MB 16.4 MB/s eta 0:00:03
#    -------------------------- ------------- 67.9/101.2 MB 15.6 MB/s eta 0:00:03
#    --------------------------- ------------ 68.4/101.2 MB 16.0 MB/s eta 0:00:03
#    --------------------------- ------------ 69.1/101.2 MB 15.2 MB/s eta 0:00:03
#    --------------------------- ------------ 69.9/101.2 MB 15.2 MB/s eta 0:00:03
#    --------------------------- ------------ 70.8/101.2 MB 14.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.6/101.2 MB 15.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 72.3/101.2 MB 14.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 73.3/101.2 MB 14.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 74.2/101.2 MB 14.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 75.1/101.2 MB 14.6 MB/s eta 0:00:02
#    ------------------------------ --------- 76.0/101.2 MB 15.2 MB/s eta 0:00:02
#    ------------------------------ --------- 76.8/101.2 MB 15.6 MB/s eta 0:00:02
#    ------------------------------ --------- 77.7/101.2 MB 16.4 MB/s eta 0:00:02
#    ------------------------------- -------- 78.6/101.2 MB 17.7 MB/s eta 0:00:02
#    ------------------------------- -------- 79.5/101.2 MB 18.2 MB/s eta 0:00:02
#    ------------------------------- -------- 80.3/101.2 MB 17.7 MB/s eta 0:00:02
#    -------------------------------- ------- 81.1/101.2 MB 18.2 MB/s eta 0:00:02
#    -------------------------------- ------- 82.1/101.2 MB 17.7 MB/s eta 0:00:02
#    -------------------------------- ------- 82.9/101.2 MB 18.2 MB/s eta 0:00:02
#    --------------------------------- ------ 83.7/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------- ------ 84.6/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------- ------ 85.0/101.2 MB 18.2 MB/s eta 0:00:01
#    --------------------------------- ------ 85.7/101.2 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 86.0/101.2 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 86.9/101.2 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 87.7/101.2 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 88.5/101.2 MB 16.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 89.2/101.2 MB 16.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 90.1/101.2 MB 16.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 90.9/101.2 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------ --- 91.8/101.2 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------ --- 92.7/101.2 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 93.6/101.2 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 94.5/101.2 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 95.3/101.2 MB 16.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.2/101.2 MB 17.2 MB/s eta 0:00:01
#    -------------------------------------- - 97.1/101.2 MB 17.7 MB/s eta 0:00:01
#    -------------------------------------- - 98.0/101.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  98.9/101.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  99.8/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  100.7/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  101.2/101.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 101.2/101.2 MB 2.1 MB/s eta 0:00:00
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    ---------------------------------------- 47.1/47.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.2.5 graphviz-0.20.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\andjelami\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb
import lightgbm as lgb
import catboost as cb

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score, roc_curve, precision_score, recall_score, f1_score, precision_recall_curve

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'AdaBoost': AdaBoostClassifier(),
    'Bagging': BaggingClassifier(),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'LightGBM': lgb.LGBMClassifier(),
    'CatBoost': cb.CatBoostClassifier(silent=True)
}
# Out:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
results_no_tuning = {}
for model_name, model in models.items():
    print(f"Training {model_name} without hyperparameter tuning...")
    model.fit(X_train_bal, y_train_bal)
    y_pred = model.predict(X_test)
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    
    results_no_tuning[model_name] = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred),
        'ROC AUC': roc_auc_score(y_test, y_pred_prob),
        'Confusion Matrix': confusion_matrix(y_test, y_pred),
        'Classification Report': classification_report(y_test, y_pred)
    }
# Out:
# Training Logistic Regression without hyperparameter tuning...
# Training Decision Tree without hyperparameter tuning...
# Training Random Forest without hyperparameter tuning...
# Training Gradient Boosting without hyperparameter tuning...
# Training AdaBoost without hyperparameter tuning...
# Training Bagging without hyperparameter tuning...
# Training XGBoost without hyperparameter tuning...
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# Training LightGBM without hyperparameter tuning...
# [LightGBM] [Info] Number of positive: 909, number of negative: 909
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001459 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 1818, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training CatBoost without hyperparameter tuning...

# %%
for model_name, result in results_no_tuning.items():
    print(f"Model: {model_name}")
    print(f"Accuracy: {result['Accuracy']}")
    print(f"Precision: {result['Precision']}")
    print(f"Recall: {result['Recall']}")
    print(f"F1 Score: {result['F1 Score']}")
    print(f"ROC AUC: {result['ROC AUC']}")
    print(f"Confusion Matrix:\n{result['Confusion Matrix']}")
    print(f"Classification Report:\n{result['Classification Report']}\n")

    # Plot Confusion Matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(result['Confusion Matrix'], annot=True, fmt='d', cmap='Blues', xticklabels=['No Attrition', 'Attrition'], yticklabels=['No Attrition', 'Attrition'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix for {model_name} (No Tuning)')
    plt.show()
    
    # Plot ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {result["ROC AUC"]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {model_name} (No Tuning)')
    plt.legend()
    plt.show()
    
    # Plot Precision-Recall curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'{model_name}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve for {model_name} (No Tuning)')
    plt.legend()
    plt.show()
# Out:
# Model: Logistic Regression
# Accuracy: 0.7444444444444445
# Precision: 0.3488372093023256
# Recall: 0.6976744186046512
# F1 Score: 0.46511627906976744
# ROC AUC: 0.8227640610593177
# Confusion Matrix:
# [[171  56]
#  [ 13  30]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83       227
#            1       0.35      0.70      0.47        43
#
#     accuracy                           0.74       270
#    macro avg       0.64      0.73      0.65       270
# weighted avg       0.84      0.74      0.77       270
# Model: Decision Tree
# Accuracy: 0.7037037037037037
# Precision: 0.2465753424657534
# Recall: 0.4186046511627907
# F1 Score: 0.3103448275862069
# ROC AUC: 0.5881569511320562
# Confusion Matrix:
# [[172  55]
#  [ 25  18]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81       227
#            1       0.25      0.42      0.31        43
#
#     accuracy                           0.70       270
#    macro avg       0.56      0.59      0.56       270
# weighted avg       0.77      0.70      0.73       270
# Model: Random Forest
# Accuracy: 0.8481481481481481
# Precision: 0.5333333333333333
# Recall: 0.37209302325581395
# F1 Score: 0.4383561643835616
# ROC AUC: 0.7255404159409896
# Confusion Matrix:
# [[213  14]
#  [ 27  16]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       227
#            1       0.53      0.37      0.44        43
#
#     accuracy                           0.85       270
#    macro avg       0.71      0.66      0.68       270
# weighted avg       0.83      0.85      0.84       270
# Model: Gradient Boosting
# Accuracy: 0.8
# Precision: 0.4
# Recall: 0.5116279069767442
# F1 Score: 0.44897959183673475
# ROC AUC: 0.7439811494723902
# Confusion Matrix:
# [[194  33]
#  [ 21  22]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       227
#            1       0.40      0.51      0.45        43
#
#     accuracy                           0.80       270
#    macro avg       0.65      0.68      0.66       270
# weighted avg       0.82      0.80      0.81       270
# Model: AdaBoost
# Accuracy: 0.7407407407407407
# Precision: 0.3373493975903614
# Recall: 0.6511627906976745
# F1 Score: 0.4444444444444444
# ROC AUC: 0.7688761397397806
# Confusion Matrix:
# [[172  55]
#  [ 15  28]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83       227
#            1       0.34      0.65      0.44        43
#
#     accuracy                           0.74       270
#    macro avg       0.63      0.70      0.64       270
# weighted avg       0.83      0.74      0.77       270
# Model: Bagging
# Accuracy: 0.7777777777777778
# Precision: 0.28205128205128205
# Recall: 0.2558139534883721
# F1 Score: 0.2682926829268293
# ROC AUC: 0.651111566437865
# Confusion Matrix:
# [[199  28]
#  [ 32  11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       227
#            1       0.28      0.26      0.27        43
#
#     accuracy                           0.78       270
#    macro avg       0.57      0.57      0.57       270
# weighted avg       0.77      0.78      0.77       270
# Model: XGBoost
# Accuracy: 0.8148148148148148
# Precision: 0.4222222222222222
# Recall: 0.4418604651162791
# F1 Score: 0.4318181818181818
# ROC AUC: 0.7319946726769798
# Confusion Matrix:
# [[201  26]
#  [ 24  19]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       227
#            1       0.42      0.44      0.43        43
#
#     accuracy                           0.81       270
#    macro avg       0.66      0.66      0.66       270
# weighted avg       0.82      0.81      0.82       270
# Model: LightGBM
# Accuracy: 0.825925925925926
# Precision: 0.4473684210526316
# Recall: 0.3953488372093023
# F1 Score: 0.41975308641975306
# ROC AUC: 0.7293310111668887
# Confusion Matrix:
# [[206  21]
#  [ 26  17]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       227
#            1       0.45      0.40      0.42        43
#
#     accuracy                           0.83       270
#    macro avg       0.67      0.65      0.66       270
# weighted avg       0.82      0.83      0.82       270
# Model: CatBoost
# Accuracy: 0.8333333333333334
# Precision: 0.47619047619047616
# Recall: 0.46511627906976744
# F1 Score: 0.4705882352941176
# ROC AUC: 0.7651879930335006
# Confusion Matrix:
# [[205  22]
#  [ 23  20]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       227
#            1       0.48      0.47      0.47        43
#
#     accuracy                           0.83       270
#    macro avg       0.69      0.68      0.69       270
# weighted avg       0.83      0.83      0.83       270

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grids = {
    'Logistic Regression': {
        'C': [0.01, 0.1, 1, 10, 100],
        'solver': ['lbfgs', 'liblinear']
    },
    'Decision Tree': {
        'max_depth': [None, 10, 20, 30, 40],
        'min_samples_split': [2, 5, 10]
    },
    'Random Forest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10]
    },
    'Gradient Boosting': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7]
    },
    'AdaBoost': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 1]
    },
    'Bagging': {
        'n_estimators': [10, 50, 100],
        'max_samples': [0.5, 1.0],
        'max_features': [0.5, 1.0]
    },
    'XGBoost': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7]
    },
    'LightGBM': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.2],
        'num_leaves': [31, 62, 127]
    },
    'CatBoost': {
        'iterations': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'depth': [3, 5, 7]
    }
}

# Train, tune, and evaluate models with hyperparameter tuning
results_with_tuning = {}
for model_name, model in models.items():
    print(f"Training {model_name} with hyperparameter tuning...")
    grid_search = GridSearchCV(model, param_grids[model_name], cv=3, scoring='accuracy')
    grid_search.fit(X_train_bal, y_train_bal)
    
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    y_pred_prob = best_model.predict_proba(X_test)[:, 1]
    
    results_with_tuning[model_name] = {
        'Best Params': grid_search.best_params_,
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred),
        'ROC AUC': roc_auc_score(y_test, y_pred_prob),
        'Confusion Matrix': confusion_matrix(y_test, y_pred),
        'Classification Report': classification_report(y_test, y_pred)
    }

    # Display results for models with hyperparameter tuning
    print(f"Model: {model_name}")
    print(f"Best Params: {results_with_tuning[model_name]['Best Params']}")
    print(f"Accuracy: {results_with_tuning[model_name]['Accuracy']}")
    print(f"Precision: {results_with_tuning[model_name]['Precision']}")
    print(f"Recall: {results_with_tuning[model_name]['Recall']}")
    print(f"F1 Score: {results_with_tuning[model_name]['F1 Score']}")
    print(f"ROC AUC: {results_with_tuning[model_name]['ROC AUC']}")
    print(f"Confusion Matrix:\n{results_with_tuning[model_name]['Confusion Matrix']}")
    print(f"Classification Report:\n{results_with_tuning[model_name]['Classification Report']}\n")

    # Plot Confusion Matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(results_with_tuning[model_name]['Confusion Matrix'], annot=True, fmt='d', cmap='Blues', xticklabels=['No Attrition', 'Attrition'], yticklabels=['No Attrition', 'Attrition'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix for {model_name} (With Tuning)')
    plt.show()
    
    # Plot ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {results_with_tuning[model_name]["ROC AUC"]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {model_name} (With Tuning)')
    plt.legend()
    plt.show()
    
    # Plot Precision-Recall curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, label=f'{model_name}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve for {model_name} (With Tuning)')
    plt.legend()
    plt.show()
# Out:
# Training Logistic Regression with hyperparameter tuning...
# Model: Logistic Regression
# Best Params: {'C': 0.1, 'solver': 'lbfgs'}
# Accuracy: 0.7592592592592593
# Precision: 0.36585365853658536
# Recall: 0.6976744186046512
# F1 Score: 0.48000000000000004
# ROC AUC: 0.8212273332650344
# Confusion Matrix:
# [[175  52]
#  [ 13  30]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84       227
#            1       0.37      0.70      0.48        43
#
#     accuracy                           0.76       270
#    macro avg       0.65      0.73      0.66       270
# weighted avg       0.84      0.76      0.79       270
# Training Decision Tree with hyperparameter tuning...
# Model: Decision Tree
# Best Params: {'max_depth': None, 'min_samples_split': 2}
# Accuracy: 0.7148148148148148
# Precision: 0.2571428571428571
# Recall: 0.4186046511627907
# F1 Score: 0.3185840707964601
# ROC AUC: 0.5947648806474747
# Confusion Matrix:
# [[175  52]
#  [ 25  18]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82       227
#            1       0.26      0.42      0.32        43
#
#     accuracy                           0.71       270
#    macro avg       0.57      0.59      0.57       270
# weighted avg       0.78      0.71      0.74       270
# Training Random Forest with hyperparameter tuning...
# Model: Random Forest
# Best Params: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# Accuracy: 0.8555555555555555
# Precision: 0.5714285714285714
# Recall: 0.37209302325581395
# F1 Score: 0.45070422535211263
# ROC AUC: 0.7626267800430284
# Confusion Matrix:
# [[215  12]
#  [ 27  16]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       227
#            1       0.57      0.37      0.45        43
#
#     accuracy                           0.86       270
#    macro avg       0.73      0.66      0.68       270
# weighted avg       0.84      0.86      0.84       270
# Training Gradient Boosting with hyperparameter tuning...
# Model: Gradient Boosting
# Best Params: {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 200}
# Accuracy: 0.8222222222222222
# Precision: 0.42424242424242425
# Recall: 0.32558139534883723
# F1 Score: 0.368421052631579
# ROC AUC: 0.7115049687532015
# Confusion Matrix:
# [[208  19]
#  [ 29  14]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       227
#            1       0.42      0.33      0.37        43
#
#     accuracy                           0.82       270
#    macro avg       0.65      0.62      0.63       270
# weighted avg       0.81      0.82      0.81       270
# Training AdaBoost with hyperparameter tuning...
# Model: AdaBoost
# Best Params: {'learning_rate': 1, 'n_estimators': 200}
# Accuracy: 0.7518518518518519
# Precision: 0.32857142857142857
# Recall: 0.5348837209302325
# F1 Score: 0.4070796460176991
# ROC AUC: 0.6905030222313288
# Confusion Matrix:
# [[180  47]
#  [ 20  23]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84       227
#            1       0.33      0.53      0.41        43
#
#     accuracy                           0.75       270
#    macro avg       0.61      0.66      0.63       270
# weighted avg       0.81      0.75      0.77       270
# Training Bagging with hyperparameter tuning...
# Model: Bagging
# Best Params: {'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100}
# Accuracy: 0.8481481481481481
# Precision: 0.5357142857142857
# Recall: 0.3488372093023256
# F1 Score: 0.4225352112676056
# ROC AUC: 0.716729843253765
# Confusion Matrix:
# [[214  13]
#  [ 28  15]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       227
#            1       0.54      0.35      0.42        43
#
#     accuracy                           0.85       270
#    macro avg       0.71      0.65      0.67       270
# weighted avg       0.83      0.85      0.83       270
# Training XGBoost with hyperparameter tuning...
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:345: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:336: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\Users\andjelami\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\data.py:314: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 909, number of negative: 909
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 1818, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Model: LightGBM
# Best Params: {'learning_rate': 0.1, 'n_estimators': 200, 'num_leaves': 31}
# Accuracy: 0.8296296296296296
# Precision: 0.45714285714285713
# Recall: 0.37209302325581395
# F1 Score: 0.41025641025641024
# ROC AUC: 0.7254379674213708
# Confusion Matrix:
# [[208  19]
#  [ 27  16]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       227
#            1       0.46      0.37      0.41        43
#
#     accuracy                           0.83       270
#    macro avg       0.67      0.64      0.66       270
# weighted avg       0.82      0.83      0.82       270
# Training CatBoost with hyperparameter tuning...
# Model: CatBoost
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.1}
# Accuracy: 0.837037037037037
# Precision: 0.4883720930232558
# Recall: 0.4883720930232558
# F1 Score: 0.4883720930232558
# ROC AUC: 0.7403954512857289
# Confusion Matrix:
# [[205  22]
#  [ 22  21]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       227
#            1       0.49      0.49      0.49        43
#
#     accuracy                           0.84       270
#    macro avg       0.70      0.70      0.70       270
# weighted avg       0.84      0.84      0.84       270
